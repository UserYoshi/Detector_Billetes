# %% [markdown]
# <a href="https://colab.research.google.com/github/UserYoshi/Detector_Billetes/blob/main/Redes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Detección de Billetes***

# %% [markdown]
# # 1. Librerias

# %%
# !pip install roboflow ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 59.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 79.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 87.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 118.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 2. Descarga del DataSet

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="lt3WoTZ25WrjbIc2PcsJ")
project = rf.workspace("billetes-y5vbu").project("billetes-7i64h")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to billetes-3 in yolov11:: 100%|██████████| 1884/1884 [00:00<00:00, 8644.84it/s]

# %% [markdown]
# # 3. Carga del modelo base ***YOLO V11***

# %%
from ultralytics import YOLO
model = YOLO('yolo11s.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 18.4M/18.4M [00:00<00:00, 68.4MB/s]

# %% [markdown]
# # 4. Entrenamiento del modelo

# %%
data_path = "/content/billetes-3/data.yaml"
results = model.train(data=data_path, epochs=70, imgsz=640)
# Out:
# Ultralytics 8.3.165 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # 5. Predicciones

# %%
# Cargamos el modelo ya entrenado
custom_model = YOLO("/content/runs/detect/train2/weights/best.pt")

# %%
# Realizamos predicciones sobre algunas imágenes
res = custom_model("/content/billetes-3/test/images")
# Out:
# image 1/93 /content/billetes-3/test/images/IMG_20250530_133352_jpg.rf.655ae9a17b9ddd21c30fa2e184de99db.jpg: 640x640 1 100000, 15.6ms
# image 2/93 /content/billetes-3/test/images/IMG_20250530_133537_jpg.rf.e346f286faa630d16f6872bc4b1df93c.jpg: 640x640 1 100000, 15.6ms
# image 3/93 /content/billetes-3/test/images/IMG_20250601_182552_jpg.rf.09277a9914ed348020c09739c9a6c352.jpg: 640x640 1 5000, 15.6ms
# image 4/93 /content/billetes-3/test/images/IMG_20250601_182734_jpg.rf.e1ab3bd0205342738957492bcbd490fe.jpg: 640x640 1 5000, 15.6ms
# image 5/93 /content/billetes-3/test/images/IMG_20250603_194316_jpg.rf.02fa727e80daffec5121709ff76862ef.jpg: 640x640 1 50000, 15.6ms
# image 6/93 /content/billetes-3/test/images/IMG_20250603_194324_jpg.rf.cb930819a2b19dd53047612e7b16b8ac.jpg: 640x640 1 50000, 15.6ms
# image 7/93 /content/billetes-3/test/images/IMG_20250603_194350_jpg.rf.af6114fd34d228d6172fe17dff52a2b6.jpg: 640x640 1 50000, 15.6ms
# ...

# %%
# Visualizamos los resultados de las detecciones
res [89].show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-9-1331914293.py in <cell line: 0>()
#       1 # Visualizamos los resultados de las detecciones
# ----> 2 res[89].show()
#
# NameError: name 'res' is not defined
